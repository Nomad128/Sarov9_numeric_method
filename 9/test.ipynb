# %%
import matplotlib.style
import numpy as np
import matplotlib.pyplot as plt
from scipy.fft import fft,ifft,fftfreq,fftshift
from scipy import signal
matplotlib.style.use('seaborn')

# %%
def super_gaussian(x, amplitude=1.0, center=0.0, sigma=1.0, expon=2.0):
    ...
    return ((amplitude/(np.sqrt(2*np.pi)*sigma))* np.exp(-abs(x-center)**expon / (2*sigma**expon)))

# %%
L = 900
x = 5*np.arange(0,L)/L
for i in range(10):
    L = 2**i
    x = 5*np.arange(0,L)/L
    print(f'{i},typy i is {type(i)}')
    i = int(i)
    x1 = x1[::i]
    x1 = np.hstack((x1,np.zeros(x.shape[0]-x1.shape[0])))
    dx = x1[1]-x1[0]

    # sig - ширина, р - скорость роста
    sig = signal.general_gaussian(256,p=10,sig=0.2*L)
    sig = sig[::i]
    plt.plot(x1,sig)
    plt.show()
    plt.scatter(x1,sig)
    plt.show()
    dw = 2*np.pi/x1[-1]
    w = np.arange(-L/2,L/2) * dw
    w = w[::i]
    print(f'Step discrete w = {dw:.3f}\n'
          f'step dis x = {dx}')

    furg = fftshift(fft(fftshift(sig)))
    plt.scatter(w,furg)
    plt.show()
    y = fftshift(ifft(fftshift(furg)))
    plt.plot(y)
    plt.show()
    print('\n\n')
# Out:
# 0,typy i is <class 'int'>
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-154-28827046dbe2> in <module>
#       6     print(f'{i},typy i is {type(i)}')
#       7     i = int(i)
# ----> 8     x1 = x1[::i]
#       9     x1 = np.hstack((x1,np.zeros(x.shape[0]-x1.shape[0])))
#      10     dx = x1[1]-x1[0]
#
# ValueError: slice step cannot be zero

# %% [markdown]
# ---

# %%
# 3 s and 300 hz
time = 1
sq = 2**12
L = time * sq
x = time*np.arange(0,L)/L
dx = x[1]-x[0]

# %%
# sig - ширина, р - скорость роста
sig = signal.general_gaussian(L,p=40,sig=0.3*L)
plt.plot(x,sig)
plt.show()

# %%
plt.scatter(x,np.abs(sig))
plt.show()

# %%
dw = 2*np.pi/x[-1]
w = np.arange(-L/2,L/2) * dw
print(f'Step discrete w = {dw:.3f}\n'
      f'step dis x = {dx}')
# Out:
# Step discrete w = 6.285
# step dis x = 0.000244140625

# %%
furg = fftshift(fft(fftshift(sig)))
plt.scatter(w,np.abs(furg))
plt.show()

# %%
y = fftshift(ifft(fftshift(furg)))
plt.scatter(x,y)
plt.show()
plt.plot(y)
print('\n\n')
# Out:
# /home/nomadpd/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:171: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order, subok=True)
# /home/nomadpd/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
k = 2
# k = int(L/time/hz)
sig1 = sig[::k]
# sig1 = np.array(None)
# x1 = np.array(None)
# w1 = np.array(None)
# p = 0
# while p < L:
#     np.append(sig1,sig[p])
#     np.append(x1,x[p])
#     np.append(w1,w[p])
#     p+=1
# np.append(sig1,sig[-1])
# np.append(x1,x[-1])
# np.append(w1,w[-1])

# np.append(sig1,sig[-1])
x1 = x[::k]
plt.plot(x1,sig1)
plt.show()
dx1 = x1[1]-x1[0]
w1 = w[::k]
dw1 = w1[1]-w1[0]
furg1 = fftshift(fft(fftshift(sig1)))*int(dw1/dw)
plt.scatter(w1,np.abs(furg1))
plt.show()

# %%
y1 = fftshift(ifft(fftshift(furg1),n=L,overwrite_x=False))
plt.scatter(x,np.abs(y1))
plt.show()
plt.figure(figsize=(12,6))
plt.plot(x,y)
plt.scatter(x1,sig1)
plt.plot(x,np.abs(y1))
plt.xlim(0.186,0.219)
print('\n\n')
# Out:
# /home/nomadpd/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:102: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
y1 = fftshift(ifft(fftshift(furg1),n=L))
# plt.scatter(x,np.abs(y1))
# plt.show()
plt.figure(figsize=(12,6))
# plt.plot(x,y)
plt.scatter(x1,sig1)
plt.plot(x,np.abs(y1))
plt.xlim(0.78,0.805)
print('\n\n')

# %%
dw
dw1
# Out:
# 63.04199304862459
